# %% [markdown]
# # Analysing emodnet files

# %%
import xarray as xr
import numpy as np

# %%
# %matplotlib inline

# %%
datc2 = xr.open_dataset('/Users/brey/Downloads/C2.mnt')

# %%
v2=datc2.DEPTH.max(); v1 = datc2.DEPTH.min()

# %%
datc2.DEPTH.plot(vmin=v1, vmax=v2, cmap='viridis_r')

# %%
np.sum(np.isnan(datc2.DEPTH.values))
# Out:
# 34447597

# %%
np.sum(datc2.DEPTH.values>0.)
# Out:
# /Users/brey/miniconda3/envs/dev/lib/python2.7/site-packages/ipykernel_launcher.py:1: RuntimeWarning: invalid value encountered in greater
#   """Entry point for launching an IPython kernel.
# 120502

# %%
datc4 = xr.open_dataset('/Users/brey/Downloads/C4.mnt')

# %%
datd4 = xr.open_dataset('/Users/brey/Downloads/D4.mnt')

# %%
xr.concat([datc4,datd4])
# Out:
# /Users/brey/miniconda3/envs/dev/lib/python2.7/site-packages/ipykernel_launcher.py:1: FutureWarning: the `dim` argument to `concat` will be required in a future version of xarray; for now, setting it to the old default of 'concat_dim'
#   """Entry point for launching an IPython kernel.
